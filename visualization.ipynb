# %%
import cocoex  # experimentation module
import numpy as np

import matplotlib.pyplot as plt

# %%
suite = cocoex.Suite("bbob", "", "")

problem = suite[0]

# %%
grid_x, grid_y = np.meshgrid(np.linspace(-4, 4, 100), np.linspace(-4, 4, 100))

grid_z = np.zeros(grid_x.shape)
for i in range(grid_x.shape[0]):
    for j in range(grid_x.shape[1]):
        grid_z[i, j] = problem(np.array([grid_x[i, j], grid_y[i, j]]))

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(grid_x, grid_y, grid_z)
plt.show()

# %%
np.random.randn(3)
# Out:
# array([ 0.09065538, -0.05891733, -0.08600362])
